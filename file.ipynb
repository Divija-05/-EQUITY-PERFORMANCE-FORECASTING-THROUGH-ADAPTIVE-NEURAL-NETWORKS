# %%
# Let me create the Mermaid code for the System Architecture diagram
system_architecture_mermaid = """
graph TB
    subgraph "Layer 1: Presentation Layer"
        A[Streamlit Web Interface]
        B[Real-time Status Display]
        C[Interactive Charts]
        D[User Controls]
    end
    
    subgraph "Layer 2: Application Layer"
        E[ModelConfig Class]
        F[Business Logic]
        G[Parameter Management]
        H[SHA-256 Hashing]
    end
    
    subgraph "Layer 3: Model Layer"
        I[LSTM Networks]
        J[Attention Mechanisms]
        K[Model Training]
        L[Prediction Engine]
    end
    
    subgraph "Layer 4: Data Processing Layer"
        M[Technical Indicators]
        N[Sentiment Generation]
        O[Feature Engineering]
        P[Data Validation]
    end
    
    subgraph "Layer 5: Data Access Layer"
        Q[Yahoo Finance API]
        R[Demo Data Files]
        S[Synthetic Data]
        T[Intelligent Caching]
    end
    
    subgraph "Layer 6: Infrastructure Layer"
        U[Logging System]
        V[Error Handling]
        W[Performance Monitoring]
        X[System Health]
    end
    
    A --> E
    B --> F
    C --> I
    D --> G
    
    E --> I
    F --> J
    G --> K
    H --> L
    
    I --> M
    J --> N
    K --> O
    L --> P
    
    M --> Q
    N --> R
    O --> S
    P --> T
    
    Q --> U
    R --> V
    S --> W
    T --> X
    
    style A fill:#e1f5fe
    style E fill:#f3e5f5
    style I fill:#e8f5e8
    style M fill:#fff3e0
    style Q fill:#fce4ec
    style U fill:#f1f8e9
"""

print("System Architecture Mermaid Code:")
print("="*50)
print(system_architecture_mermaid)
print("\n" + "="*50)

# Workflow Model Mermaid
workflow_mermaid = """
flowchart TD
    A[Start Analysis] --> B{Internet Connected?}
    B -->|Yes| C[Fetch Live API Data]
    B -->|No| D[Load Demo Data]
    
    C --> E{Data Quality OK?}
    E -->|Yes| F[Process Data]
    E -->|No| G[Retry with Backoff]
    G --> H{Max Retries?}
    H -->|No| C
    H -->|Yes| D
    
    D --> I[Load CSV/JSON Files]
    I --> J{Files Available?}
    J -->|Yes| F
    J -->|No| K[Generate Synthetic Data]
    K --> F
    
    F --> L[Calculate Technical Indicators]
    L --> M[Generate Market Sentiment]
    M --> N[Feature Engineering]
    N --> O{Model Cached?}
    
    O -->|Yes| P[Load Cached Model]
    O -->|No| Q[Train New Model]
    Q --> R[Save Model to Cache]
    R --> S[Generate Predictions]
    P --> S
    
    S --> T[Create Trading Signals]
    T --> U[Backtesting Analysis]
    U --> V[Display Results]
    V --> W[Update Performance Metrics]
    W --> X[End]
    
    style A fill:#e8f5e8
    style F fill:#e1f5fe
    style S fill:#fff3e0
    style V fill:#f3e5f5
"""

print("Workflow Model Mermaid Code:")
print("="*50)
print(workflow_mermaid)
print("\n" + "="*50)
# Out:
# System Architecture Mermaid Code:
# ...
#
# graph TB
#     subgraph "Layer 1: Presentation Layer"
#         A[Streamlit Web Interface]
#         B[Real-time Status Display]
#         C[Interactive Charts]
#         D[User Controls]
#     end
#
#     subgraph "Layer 2: Application Layer"
#         E[ModelConfig Class]
#         F[Business Logic]
#         G[Parameter Management]
#         H[SHA-256 Hashing]
#     end
#
#     subgraph "Layer 3: Model Layer"
#         I[LSTM Networks]
#         J[Attention Mechanisms]
#         K[Model Training]
#         L[Prediction Engine]
#     end
#
#     subgraph "Layer 4: Data Processing Layer"
#         M[Technical Indicators]
#         N[Sentiment Generation]
#         O[Feature Engineering]
#         P[Data Validation]
#     end
#
#     subgraph "Layer 5: Data Access Layer"
#         Q[Yahoo Finance API]
#         R[Demo Data Files]
#         S[Synthetic Data]
#         T[Intelligent Caching]
#     end
#
# ...
